# %% [markdown]
# # 3M

# %% [markdown]
# Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              aa24
#                   Model     MAE    MSE    RMSE      R2  RMSLE    MAPE  \
# ada  AdaBoost Regressor  0.0543  0.005  0.0708  0.6253  0.056  7.5029
#
#      TT (Sec)
# ada     0.302
#                 Model    MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.036  0.0025  0.0504 -0.0293  0.0387  5.7443
#                 Model     MAE     MSE   RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.0435  0.0026  0.051  0.1857  0.0459  0.9131
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0025   0.0026
# R-squared.........:  -0.0293   0.1857
#
#
#
#
#   Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 15)
# 5   Transformed train set shape        (3976, 15)
# 6    Transformed test set shape         (994, 15)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14            Feature selection              True
# 15     Feature selection method           classic
# 16  Feature selection estimator          lightgbm
# 17  Number of features selected               0.2
# 18               Fold Generator             KFold
# 19                  Fold Number                10
# 20                     CPU Jobs                -1
# 21                      Use GPU             False
# 22               Log Experiment             False
# 23              Experiment Name  reg-default-name
# 24                          USI              6fcd
#                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0153  0.0013  0.0354  0.9043  0.0274  5.0679
#
#     TT (Sec)
# et    79.392
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0359  0.0028  0.0527 -0.1278  0.0252  3.6278
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0421  0.0031  0.0556  0.0343  0.0485  0.8352
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0028   0.0031
# R-squared.........:  -0.1278   0.0343
#
#
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 15)
# 5   Transformed train set shape        (3976, 15)
# 6    Transformed test set shape         (994, 15)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14            Feature selection              True
# 15     Feature selection method           classic
# 16  Feature selection estimator          lightgbm
# 17  Number of features selected               0.2
# 18               Fold Generator             KFold
# 19                  Fold Number                10
# 20                     CPU Jobs                -1
# 21                      Use GPU             False
# 22               Log Experiment             False
# 23              Experiment Name  reg-default-name
# 24                          USI              b6b9
#                  Model     MAE     MSE    RMSE     R2   RMSLE   MAPE  TT (Sec)
# huber  Huber Regressor  0.0536  0.0056  0.0745  0.587  0.0564  6.881    72.984
#              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Huber Regressor  0.0398  0.0024  0.0486  0.0399  0.0323  2.9956
#              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Huber Regressor  0.0441  0.0026  0.0506  0.1995  0.0443  0.9737
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0024   0.0026
# R-squared.........:   0.0399   0.1995
#
#
#
# Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 15)
# 5   Transformed train set shape        (3976, 15)
# 6    Transformed test set shape         (994, 15)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14            Feature selection              True
# 15     Feature selection method           classic
# 16  Feature selection estimator          lightgbm
# 17  Number of features selected               0.2
# 18               Fold Generator             KFold
# 19                  Fold Number                10
# 20                     CPU Jobs                -1
# 21                      Use GPU             False
# 22               Log Experiment             False
# 23              Experiment Name  reg-default-name
# 24                          USI              04e2
#                   Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# ada  AdaBoost Regressor  0.0573  0.0052  0.0722  0.6109  0.0563  8.8249
#
#      TT (Sec)
# ada    75.672
#                 Model    MAE     MSE    RMSE      R2  RMSLE    MAPE
# 0  AdaBoost Regressor  0.036  0.0026  0.0515 -0.0747  0.033  5.3706
#                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.0405  0.0025  0.0496  0.2308  0.0428  0.9224
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0026   0.0025
# R-squared.........:  -0.0747   0.2308
#
#
# Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (3242, 72)
# 4        Transformed data shape        (3242, 72)
# 5   Transformed train set shape        (2593, 72)
# 6    Transformed test set shape         (649, 72)
# 7              Numeric features                71
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              083b
#                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0141  0.0014  0.0358  0.8807  0.0266  8.0657
#
#     TT (Sec)
# et     0.299
#                    Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0352  0.002  0.0449  0.1807  0.0337  4.5202
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0639  0.0062  0.0784 -0.9231  0.0668  1.0914
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0020   0.0062
# R-squared.........:   0.1807  -0.9231
#
#
#
#
#  Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (3242, 72)
# 4        Transformed data shape        (3242, 72)
# 5   Transformed train set shape        (2593, 72)
# 6    Transformed test set shape         (649, 72)
# 7              Numeric features                71
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              2436
#                            Model     MAE     MSE    RMSE      R2   RMSLE  \
# gbr  Gradient Boosting Regressor  0.0227  0.0019  0.0426  0.8317  0.0319
#
#         MAPE  TT (Sec)
# gbr  10.0117     0.742
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0334  0.0021  0.0458  0.1493  0.0321  5.3788
#                          Model     MAE    MSE    RMSE     R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0529  0.005  0.0706 -0.558  0.0596  0.8985
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0021   0.0050
# R-squared.........:   0.1493  -0.5580
#
#
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (3242, 73)
# 4        Transformed data shape        (3242, 73)
# 5   Transformed train set shape        (2593, 73)
# 6    Transformed test set shape         (649, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              b2c6
#                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0141  0.0014  0.0365  0.8751  0.0264  7.4205
#
#     TT (Sec)
# et     0.309
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0353  0.0021  0.0456  0.1556  0.0313  3.7403
#                    Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0549  0.005  0.0706 -0.5592  0.0608  1.0089
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0021   0.0050
# R-squared.........:   0.1556  -0.5592
#
#
#
# Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (3242, 73)
# 4        Transformed data shape        (3242, 73)
# 5   Transformed train set shape        (2593, 73)
# 6    Transformed test set shape         (649, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              f6c6
#                                     Model     MAE     MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.0174  0.0016  0.0386  0.8611
#
#            RMSLE     MAPE  TT (Sec)
# lightgbm  0.0285  10.3483   131.499
#                              Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0324  0.002  0.0449  0.1812  0.0313  4.1512
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0662  0.0066  0.0813 -1.0662  0.0682  1.2376
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0020   0.0066
# R-squared.........:   0.1812  -1.0662
#
#
#
# Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (3242, 73)
# 4        Transformed data shape        (3242, 73)
# 5   Transformed train set shape        (2593, 73)
# 6    Transformed test set shape         (649, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              01e6
#                            Model    MAE     MSE    RMSE      R2  RMSLE  \
# gbr  Gradient Boosting Regressor  0.023  0.0019  0.0428  0.8303  0.032
#
#         MAPE  TT (Sec)
# gbr  11.5758     0.764
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0295  0.0017  0.0409  0.3207  0.0285  4.3631
#                          Model     MAE     MSE    RMSE      R2  RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0542  0.0049  0.0703 -0.5428  0.058  0.9699
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0017   0.0049
# R-squared.........:   0.3207  -0.5428
#
#
#
#
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (3242, 73)
# 4        Transformed data shape        (3242, 73)
# 5   Transformed train set shape        (2593, 73)
# 6    Transformed test set shape         (649, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              5101
#                   Model     MAE     MSE    RMSE      R2   RMSLE     MAPE  \
# ada  AdaBoost Regressor  0.0467  0.0041  0.0636  0.6287  0.0496  11.0855
#
#      TT (Sec)
# ada     0.178
#                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.0343  0.0021  0.0453  0.1667  0.0342  5.7995
#                 Model     MAE     MSE   RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.0425  0.0027  0.052  0.1544  0.0451  0.9256
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0021   0.0027
# R-squared.........:   0.1667   0.1544

# %% [markdown]
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1653, 73)
# 4        Transformed data shape        (1653, 73)
# 5   Transformed train set shape        (1322, 73)
# 6    Transformed test set shape         (331, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              79a0
#                 Model     MAE     MSE    RMSE     R2   RMSLE    MAPE  TT (Sec)
# lr  Linear Regression  0.0379  0.0035  0.0577  0.606  0.0446  1.2354     0.323
#                Model    MAE    MSE    RMSE      R2  RMSLE    MAPE
# 0  Linear Regression  0.132  0.023  0.1516 -6.0625  0.128  4.4475
#                Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  Linear Regression  0.0611  0.006  0.0776 -1.6418  0.0604  0.6518
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0230   0.0060
# R-squared.........:  -6.0625  -1.6418
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1784, 73)
# 4        Transformed data shape        (1784, 73)
# 5   Transformed train set shape        (1427, 73)
# 6    Transformed test set shape         (357, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              00d8
#                 Model     MAE    MSE    RMSE      R2   RMSLE    MAPE  TT (Sec)
# lr  Linear Regression  0.0278  0.002  0.0442  0.7511  0.0337  2.2943     0.193
#                Model     MAE     MSE   RMSE       R2   RMSLE   MAPE
# 0  Linear Regression  0.1611  0.0286  0.169 -17.0467  0.1398  7.341
#                Model     MAE     MSE   RMSE       R2   RMSLE    MAPE
# 0  Linear Regression  0.1249  0.0204  0.143 -36.1221  0.1243  2.5929
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0286   0.0204
# R-squared.........: -17.0467 -36.1221
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1533, 73)
# 4        Transformed data shape        (1533, 73)
# 5   Transformed train set shape        (1226, 73)
# 6    Transformed test set shape         (307, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              fc1b
#                 Model     MAE     MSE    RMSE     R2   RMSLE    MAPE  TT (Sec)
# lr  Linear Regression  0.0399  0.0038  0.0601  0.671  0.0461  2.8408     0.029
#                Model     MAE     MSE    RMSE       R2   RMSLE       MAPE
# 0  Linear Regression  0.1666  0.0662  0.2572 -24.1667  0.1497  39.354599
#                Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
# 0  Linear Regression  0.1669  0.0573  0.2393 -24.9378  0.1338  5.3306
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0662   0.0573
# R-squared.........: -24.1667 -24.9378
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1653, 73)
# 4        Transformed data shape        (1653, 73)
# 5   Transformed train set shape        (1322, 73)
# 6    Transformed test set shape         (331, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              e516
#                   Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# ridge  Ridge Regression  0.0376  0.0034  0.0574  0.6094  0.0444  1.2283
#
#        TT (Sec)
# ridge      0.03
#               Model    MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Ridge Regression  0.106  0.0142  0.1193 -3.3722  0.0987  3.4463
#               Model     MAE    MSE   RMSE      R2   RMSLE    MAPE
# 0  Ridge Regression  0.0545  0.005  0.071 -1.2093  0.0547  0.5555
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0142   0.0050
# R-squared.........:  -3.3722  -1.2093
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1784, 73)
# 4        Transformed data shape        (1784, 73)
# 5   Transformed train set shape        (1427, 73)
# 6    Transformed test set shape         (357, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              1c95
#                   Model     MAE    MSE    RMSE      R2   RMSLE    MAPE  \
# ridge  Ridge Regression  0.0276  0.002  0.0438  0.7555  0.0339  2.2841
#
#        TT (Sec)
# ridge     0.032
#               Model     MAE     MSE   RMSE       R2   RMSLE    MAPE
# 0  Ridge Regression  0.1591  0.0279  0.167 -16.6239  0.1379  7.2665
#               Model     MAE     MSE    RMSE       R2   RMSLE  MAPE
# 0  Ridge Regression  0.1236  0.0195  0.1395 -34.3623  0.1216  2.64
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0279   0.0195
# R-squared.........: -16.6239 -34.3623
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1533, 73)
# 4        Transformed data shape        (1533, 73)
# 5   Transformed train set shape        (1226, 73)
# 6    Transformed test set shape         (307, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              9386
#                   Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# ridge  Ridge Regression  0.0395  0.0036  0.0588  0.6859  0.0453  2.9365
#
#        TT (Sec)
# ridge     0.027
#               Model     MAE    MSE    RMSE       R2   RMSLE     MAPE
# 0  Ridge Regression  0.1568  0.059  0.2428 -21.4245  0.1399  37.6926
#               Model    MAE     MSE    RMSE       R2   RMSLE   MAPE
# 0  Ridge Regression  0.151  0.0502  0.2241 -21.7336  0.1257  4.847
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0590   0.0502
# R-squared.........: -21.4245 -21.7336
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1653, 73)
# 4        Transformed data shape        (1653, 73)
# 5   Transformed train set shape        (1322, 73)
# 6    Transformed test set shape         (331, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              0930
#                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0179  0.0017  0.0401  0.8044  0.0285  0.4966
#
#     TT (Sec)
# et     0.163
#                    Model     MAE     MSE    RMSE     R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0833  0.0077  0.0879 -1.374  0.0787  2.5998
#                    Model     MAE     MSE    RMSE      R2  RMSLE    MAPE
# 0  Extra Trees Regressor  0.0859  0.0089  0.0944 -2.9064  0.073  0.8671
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0077   0.0089
# R-squared.........:  -1.3740  -2.9064
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1784, 73)
# 4        Transformed data shape        (1784, 73)
# 5   Transformed train set shape        (1427, 73)
# 6    Transformed test set shape         (357, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              a477
#                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0131  0.0011  0.0317  0.8661  0.0239  1.1113
#
#     TT (Sec)
# et     0.172
#                    Model    MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.037  0.0023  0.0479 -0.4516  0.0308  1.6761
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0209  0.0008  0.0277 -0.3943  0.0189  0.8049
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0023   0.0008
# R-squared.........:  -0.4516  -0.3943
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1533, 73)
# 4        Transformed data shape        (1533, 73)
# 5   Transformed train set shape        (1226, 73)
# 6    Transformed test set shape         (307, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              1352
#                     Model    MAE     MSE    RMSE     R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.016  0.0017  0.0384  0.863  0.0295  0.9448
#
#     TT (Sec)
# et     0.149
#                    Model     MAE     MSE    RMSE      R2   RMSLE     MAPE
# 0  Extra Trees Regressor  0.0769  0.0075  0.0866 -1.8516  0.0621  30.4523
#                    Model     MAE     MSE    RMSE     R2   RMSLE   MAPE
# 0  Extra Trees Regressor  0.1262  0.0227  0.1506 -9.269  0.1239  3.514
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0075   0.0227
# R-squared.........:  -1.8516  -9.2690
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1653, 73)
# 4        Transformed data shape        (1653, 73)
# 5   Transformed train set shape        (1322, 73)
# 6    Transformed test set shape         (331, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              d5ca
#                       Model     MAE     MSE    RMSE     R2   RMSLE    MAPE  \
# rf  Random Forest Regressor  0.0207  0.0018  0.0416  0.793  0.0297  0.6232
#
#     TT (Sec)
# rf     0.495
#                      Model     MAE     MSE    RMSE      R2  RMSLE    MAPE
# 0  Random Forest Regressor  0.1042  0.0117  0.1079 -2.5809  0.096  3.3788
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0874  0.0103  0.1013 -3.5044  0.0619  0.8843
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0117   0.0103
# R-squared.........:  -2.5809  -3.5044
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1784, 73)
# 4        Transformed data shape        (1784, 73)
# 5   Transformed train set shape        (1427, 73)
# 6    Transformed test set shape         (357, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              586d
#                       Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# rf  Random Forest Regressor  0.0158  0.0013  0.0349  0.8384  0.0256  1.1463
#
#     TT (Sec)
# rf     0.512
#                      Model     MAE     MSE   RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0396  0.0027  0.052 -0.7095  0.0315  1.7855
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0246  0.0012  0.0349 -1.2061  0.0233  1.0359
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0027   0.0012
# R-squared.........:  -0.7095  -1.2061
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1533, 73)
# 4        Transformed data shape        (1533, 73)
# 5   Transformed train set shape        (1226, 73)
# 6    Transformed test set shape         (307, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              d3fb
#                       Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# rf  Random Forest Regressor  0.0183  0.0019  0.0411  0.8455  0.0324  1.1406
#
#     TT (Sec)
# rf     0.434
#                      Model     MAE     MSE    RMSE      R2   RMSLE     MAPE
# 0  Random Forest Regressor  0.0669  0.0059  0.0768 -1.2435  0.0531  18.9988
#                      Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.1475  0.0305  0.1746 -12.8034  0.1452  3.7327
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0059   0.0305
# R-squared.........:  -1.2435 -12.8034
#
#
# CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1653, 73)
# 4        Transformed data shape        (1653, 73)
# 5   Transformed train set shape        (1322, 73)
# 6    Transformed test set shape         (331, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              9626
# Processing:  56%|████████████████████████████████████████████████████████████████████████████████████████▎                                                            Processing: 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████                                                                                                                                                                                                          Model     MAE     MSE   RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.0205  0.0019  0.042  0.7873
#
#            RMSLE    MAPE  TT (Sec)
# lightgbm  0.0283  0.6695   117.117
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0976  0.0104  0.1019 -2.1895  0.0913  3.1902
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0926  0.0111  0.1056 -3.8904  0.0611  0.9458
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0104   0.0111
# R-squared.........:  -2.1895  -3.8904
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1784, 73)
# 4        Transformed data shape        (1784, 73)
# 5   Transformed train set shape        (1427, 73)
# 6    Transformed test set shape         (357, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              2f43
#                                     Model     MAE     MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.0163  0.0013  0.0348  0.8401
#
#            RMSLE    MAPE  TT (Sec)
# lightgbm  0.0255  1.3953   133.913
#                              Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0482  0.004  0.0633 -1.5338  0.0344  2.0409
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0223  0.0009  0.0294 -0.5724  0.0199  0.8426
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0040   0.0009
# R-squared.........:  -1.5338  -0.5724
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1533, 73)
# 4        Transformed data shape        (1533, 73)
# 5   Transformed train set shape        (1226, 73)
# 6    Transformed test set shape         (307, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              5607
#                                     Model     MAE     MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.0184  0.0017  0.0396  0.8575
#
#            RMSLE    MAPE  TT (Sec)
# lightgbm  0.0318  1.2469    97.311
#                              Model     MAE     MSE    RMSE      R2   RMSLE     MAPE
# 0  Light Gradient Boosting Machine  0.0527  0.0037  0.0609 -0.4082  0.0386  14.1562
#                              Model     MAE     MSE    RMSE       R2   RMSLE   MAPE
# 0  Light Gradient Boosting Machine  0.1418  0.0318  0.1783 -13.3978  0.1491  3.466
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0037   0.0318
# R-squared.........:  -0.4082 -13.3978

# %%
CLUSTER NUMBER: -1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1653, 73)
4        Transformed data shape        (1653, 73)
5   Transformed train set shape        (1322, 73)
6    Transformed test set shape         (331, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              c645
                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \                                                                                                                                                                                   
knn  K Neighbors Regressor  0.0247  0.0024  0.0476  0.7281  0.0359  0.7004   

     TT (Sec)  
knn     0.395  
                   Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
0  K Neighbors Regressor  0.1316  0.0189  0.1373 -4.7971  0.1228  4.458
                   Model     MAE     MSE   RMSE      R2   RMSLE    MAPE
0  K Neighbors Regressor  0.0864  0.0104  0.102 -3.5611  0.0668  0.8727

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0189   0.0104
R-squared.........:  -4.7971  -3.5611



 CLUSTER NUMBER:  0
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1784, 73)
4        Transformed data shape        (1784, 73)
5   Transformed train set shape        (1427, 73)
6    Transformed test set shape         (357, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              6dad
                     Model     MAE     MSE    RMSE      R2  RMSLE    MAPE  \                                                                                                                                                                                    
knn  K Neighbors Regressor  0.0178  0.0015  0.0369  0.8225  0.028  1.5315   

     TT (Sec)  
knn      0.19  
                   Model   MAE     MSE    RMSE      R2   RMSLE   MAPE
0  K Neighbors Regressor  0.04  0.0024  0.0485 -0.4844  0.0381  1.914
                   Model    MAE     MSE    RMSE      R2   RMSLE    MAPE
0  K Neighbors Regressor  0.022  0.0009  0.0304 -0.6779  0.0252  0.6552

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0024   0.0009
R-squared.........:  -0.4844  -0.6779



 CLUSTER NUMBER:  1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1533, 73)
4        Transformed data shape        (1533, 73)
5   Transformed train set shape        (1226, 73)
6    Transformed test set shape         (307, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              a8a7
                     Model    MAE     MSE    RMSE      R2   RMSLE    MAPE  \                                                                                                                                                                                    
knn  K Neighbors Regressor  0.025  0.0029  0.0522  0.7543  0.0399  2.4164   

     TT (Sec)  
knn     0.028  
                   Model     MAE     MSE   RMSE      R2   RMSLE       MAPE
0  K Neighbors Regressor  0.0685  0.0062  0.079 -1.3733  0.0548  29.875099
                   Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
0  K Neighbors Regressor  0.0461  0.0065  0.0808 -1.9569  0.0423  1.7377

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0062   0.0065
R-squared.........:  -1.3733  -1.9569



 CLUSTER NUMBER: -1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1653, 73)
4        Transformed data shape        (1653, 73)
5   Transformed train set shape        (1322, 73)
6    Transformed test set shape         (331, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              150e
                           Model     MAE     MSE    RMSE      R2   RMSLE  \                                                                                                                                                                                     
gbr  Gradient Boosting Regressor  0.0259  0.0024  0.0473  0.7317  0.0342   

       MAPE  TT (Sec)  
gbr  0.7383     0.283  
                         Model     MAE     MSE    RMSE      R2  RMSLE    MAPE
0  Gradient Boosting Regressor  0.0836  0.0081  0.0897 -1.4744   0.08  2.5856
                         Model    MAE     MSE   RMSE      R2   RMSLE    MAPE
0  Gradient Boosting Regressor  0.088  0.0098  0.099 -3.2997  0.0669  0.8914

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0081   0.0098
R-squared.........:  -1.4744  -3.2997



 CLUSTER NUMBER:  0
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1784, 73)
4        Transformed data shape        (1784, 73)
5   Transformed train set shape        (1427, 73)
6    Transformed test set shape         (357, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              8619
                           Model     MAE     MSE    RMSE      R2   RMSLE  \                                                                                                                                                                                     
gbr  Gradient Boosting Regressor  0.0187  0.0013  0.0355  0.8381  0.0265   

       MAPE  TT (Sec)  
gbr  1.6729     0.308  
                         Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
0  Gradient Boosting Regressor  0.0543  0.0054  0.0736 -2.4235  0.0404  2.411
                         Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
0  Gradient Boosting Regressor  0.0287  0.0012  0.0346 -1.1774  0.0253  1.043

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0054   0.0012
R-squared.........:  -2.4235  -1.1774



 CLUSTER NUMBER:  1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1533, 73)
4        Transformed data shape        (1533, 73)
5   Transformed train set shape        (1226, 73)
6    Transformed test set shape         (307, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              f1f0
                           Model     MAE     MSE    RMSE      R2   RMSLE  \                                                                                                                                                                                     
gbr  Gradient Boosting Regressor  0.0216  0.0018  0.0411  0.8456  0.0325   

       MAPE  TT (Sec)  
gbr  1.8236     0.258  
                         Model     MAE    MSE    RMSE      R2   RMSLE     MAPE
0  Gradient Boosting Regressor  0.0417  0.003  0.0547 -0.1359  0.0427  17.2433
                         Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
0  Gradient Boosting Regressor  0.1348  0.0324  0.1801 -13.6831  0.1503  2.8442

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0030   0.0324
R-squared.........:  -0.1359 -13.6831



 CLUSTER NUMBER: -1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1653, 73)
4        Transformed data shape        (1653, 73)
5   Transformed train set shape        (1322, 73)
6    Transformed test set shape         (331, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              bc0a
                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \                                                                                                                                                                                       
huber  Huber Regressor  0.0348  0.0038  0.0604  0.5636  0.0458  1.3257   

       TT (Sec)  
huber     0.039  
             Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
0  Huber Regressor  0.1022  0.0124  0.1112 -2.7972  0.0845  3.0934
             Model     MAE     MSE    RMSE      R2   RMSLE  MAPE
0  Huber Regressor  0.0547  0.0058  0.0761 -1.5373  0.0531  0.52

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0124   0.0058
R-squared.........:  -2.7972  -1.5373



 CLUSTER NUMBER:  0
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1784, 73)
4        Transformed data shape        (1784, 73)
5   Transformed train set shape        (1427, 73)
6    Transformed test set shape         (357, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              daba
                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \                                                                                                                                                                                       
huber  Huber Regressor  0.0248  0.0019  0.0432  0.7625  0.0341  1.8603   

       TT (Sec)  
huber     0.038  
             Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
0  Huber Regressor  0.1537  0.0272  0.1649 -16.185  0.1329  6.9442
             Model     MAE     MSE   RMSE       R2   RMSLE    MAPE
0  Huber Regressor  0.1211  0.0174  0.132 -30.6575  0.1161  2.8939

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0272   0.0174
R-squared.........: -16.1850 -30.6575



 CLUSTER NUMBER:  1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1533, 73)
4        Transformed data shape        (1533, 73)
5   Transformed train set shape        (1226, 73)
6    Transformed test set shape         (307, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              9c1e
                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \                                                                                                                                                                                       
huber  Huber Regressor  0.0361  0.0039  0.0604  0.6709  0.0448  2.6273   

       TT (Sec)  
huber     0.033  
             Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
0  Huber Regressor  0.1519  0.0748  0.2735 -27.4507  0.1561  7.2348
             Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
0  Huber Regressor  0.1599  0.0582  0.2413 -25.3612  0.1319  3.2825

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0748   0.0582
R-squared.........: -27.4507 -25.3612



 CLUSTER NUMBER: -1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1653, 73)
4        Transformed data shape        (1653, 73)
5   Transformed train set shape        (1322, 73)
6    Transformed test set shape         (331, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              dd79
                  Model     MAE     MSE    RMSE    R2   RMSLE    MAPE  \                                                                                                                                                                                        
ada  AdaBoost Regressor  0.0538  0.0045  0.0666  0.48  0.0536  1.2492   

     TT (Sec)  
ada     0.095  
                Model     MAE     MSE   RMSE      R2   RMSLE    MAPE
0  AdaBoost Regressor  0.0755  0.0071  0.084 -1.1677  0.0767  2.3279
                Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
0  AdaBoost Regressor  0.0628  0.0049  0.0697 -1.1294  0.0642  0.611

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0071   0.0049
R-squared.........:  -1.1677  -1.1294



 CLUSTER NUMBER:  0
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1784, 73)
4        Transformed data shape        (1784, 73)
5   Transformed train set shape        (1427, 73)
6    Transformed test set shape         (357, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              6fa1
                  Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \                                                                                                                                                                                      
ada  AdaBoost Regressor  0.0329  0.0022  0.0457  0.7365  0.0366  2.0767   

     TT (Sec)  
ada     0.098  
                Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
0  AdaBoost Regressor  0.0324  0.0022  0.0471 -0.4008  0.0244  1.0521
                Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
0  AdaBoost Regressor  0.0346  0.0024  0.0491 -3.3816  0.0351  1.3979

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0022   0.0024
R-squared.........:  -0.4008  -3.3816



 CLUSTER NUMBER:  1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1533, 73)
4        Transformed data shape        (1533, 73)
5   Transformed train set shape        (1226, 73)
6    Transformed test set shape         (307, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              b554
                  Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \                                                                                                                                                                                      
ada  AdaBoost Regressor  0.0431  0.0036  0.0589  0.6845  0.0482  5.9156   

     TT (Sec)  
ada     0.083  
                Model     MAE     MSE    RMSE     R2   RMSLE     MAPE
0  AdaBoost Regressor  0.0912  0.0101  0.1007 -2.853  0.0719  30.1176
                Model    MAE     MSE    RMSE       R2   RMSLE    MAPE
0  AdaBoost Regressor  0.148  0.0298  0.1726 -12.4951  0.1408  4.8205

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0101   0.0298
R-squared.........:  -2.8530 -12.4951



 CLUSTER NUMBER: -1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1653, 73)
4        Transformed data shape        (1653, 73)
5   Transformed train set shape        (1322, 73)
6    Transformed test set shape         (331, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              ccf3
                           Model     MAE     MSE    RMSE      R2   RMSLE  \                                                                                                                                                                                     
omp  Orthogonal Matching Pursuit  0.0469  0.0039  0.0622  0.5473  0.0484   

       MAPE  TT (Sec)  
omp  1.6024      0.03  
                         Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
0  Orthogonal Matching Pursuit  0.1209  0.0153  0.1237 -3.7019  0.0996  3.7119
                         Model   MAE     MSE    RMSE      R2   RMSLE    MAPE
0  Orthogonal Matching Pursuit  0.13  0.0187  0.1369 -7.2245  0.0649  1.3277

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0153   0.0187
R-squared.........:  -3.7019  -7.2245



 CLUSTER NUMBER:  0
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1784, 73)
4        Transformed data shape        (1784, 73)
5   Transformed train set shape        (1427, 73)
6    Transformed test set shape         (357, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              da2c
                           Model    MAE     MSE    RMSE      R2   RMSLE  \                                                                                                                                                                                      
omp  Orthogonal Matching Pursuit  0.031  0.0022  0.0459  0.7352  0.0364   

       MAPE  TT (Sec)  
omp  2.3906     0.033  
                         Model     MAE     MSE    RMSE       R2  RMSLE    MAPE
0  Orthogonal Matching Pursuit  0.1685  0.0333  0.1825 -20.0411  0.147  7.6273
                         Model   MAE     MSE    RMSE       R2   RMSLE    MAPE
0  Orthogonal Matching Pursuit  0.12  0.0178  0.1333 -31.2802  0.1172  3.0959

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0333   0.0178
R-squared.........: -20.0411 -31.2802



 CLUSTER NUMBER:  1
                    Description             Value
0                    Session id               123
1                        Target  Rentabilidade 3M
2                   Target type        Regression
3           Original data shape        (1533, 73)
4        Transformed data shape        (1533, 73)
5   Transformed train set shape        (1226, 73)
6    Transformed test set shape         (307, 73)
7              Numeric features                72
8                    Preprocess              True
9               Imputation type            simple
10           Numeric imputation              mean
11       Categorical imputation              mode
12               Transformation              True
13        Transformation method          quantile
14               Fold Generator             KFold
15                  Fold Number                10
16                     CPU Jobs                -1
17                      Use GPU             False
18               Log Experiment             False
19              Experiment Name  reg-default-name
20                          USI              abfd
                           Model     MAE     MSE    RMSE      R2   RMSLE  \                                                                                                                                                                                     
omp  Orthogonal Matching Pursuit  0.0467  0.0046  0.0671  0.5895  0.0538   

       MAPE  TT (Sec)  
omp  3.4982     0.028  
                         Model     MAE     MSE    RMSE      R2   RMSLE       MAPE
0  Orthogonal Matching Pursuit  0.0715  0.0084  0.0919 -2.2131  0.0521  35.424999
                         Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
0  Orthogonal Matching Pursuit  0.1446  0.0295  0.1717 -12.3547  0.1372  3.0402

                          1M       2M       3M

                          1M       2M       3M
Mean Squared Error:   0.0084   0.0295
R-squared.........:  -2.2131 -12.3547

# %% [markdown]
# CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (938, 73)
# 4        Transformed data shape         (938, 73)
# 5   Transformed train set shape         (750, 73)
# 6    Transformed test set shape         (188, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              bd58
#                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0184  0.0018  0.0405  0.7843  0.0298  1.5051
#
#     TT (Sec)
# et     0.088
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0575  0.0037  0.0605 -0.1266  0.0529  1.7404
#                    Model    MAE     MSE    RMSE     R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.081  0.0078  0.0885 -2.437  0.0735  0.8108
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0037   0.0078
# R-squared.........:  -0.1266  -2.4370
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1336, 73)
# 4        Transformed data shape        (1336, 73)
# 5   Transformed train set shape        (1068, 73)
# 6    Transformed test set shape         (268, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              4c05
#                     Model     MAE     MSE    RMSE      R2   RMSLE     MAPE  \
# et  Extra Trees Regressor  0.0108  0.0005  0.0225  0.8869  0.0182  13.6938
#
#     TT (Sec)
# et     0.122
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0248  0.0012  0.0347  0.2377  0.0307  0.7781
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0342  0.0015  0.0388 -1.7304  0.0301  1.0319
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0012   0.0015
# R-squared.........:   0.2377  -1.7304
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (968, 73)
# 4        Transformed data shape         (968, 73)
# 5   Transformed train set shape         (774, 73)
# 6    Transformed test set shape         (194, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              6182
#                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0162  0.0023  0.0403  0.8126  0.0304  0.4504
#
#     TT (Sec)
# et      0.09
#                    Model     MAE   MSE  RMSE      R2   RMSLE     MAPE
# 0  Extra Trees Regressor  0.0914  0.01   0.1 -2.8002  0.0712  30.2152
#                    Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.1474  0.0277  0.1664 -11.5367  0.1322  4.4943
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0100   0.0277
# R-squared.........:  -2.8002 -11.5367
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (938, 73)
# 4        Transformed data shape         (938, 73)
# 5   Transformed train set shape         (750, 73)
# 6    Transformed test set shape         (188, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              caba
#                       Model     MAE     MSE   RMSE      R2   RMSLE    MAPE  \
# rf  Random Forest Regressor  0.0202  0.0018  0.041  0.7794  0.0293  2.2634
#
#     TT (Sec)
# rf     0.233
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0329  0.0027  0.0515  0.1845  0.0392  0.8263
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0767  0.0075  0.0865 -2.2794  0.0707  0.7746
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0027   0.0075
# R-squared.........:   0.1845  -2.2794
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1336, 73)
# 4        Transformed data shape        (1336, 73)
# 5   Transformed train set shape        (1068, 73)
# 6    Transformed test set shape         (268, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              adc2
#                       Model     MAE     MSE    RMSE      R2   RMSLE     MAPE  \
# rf  Random Forest Regressor  0.0127  0.0007  0.0259  0.8455  0.0197  16.0503
#
#     TT (Sec)
# rf     0.348
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0279  0.0017  0.0406 -0.0431  0.0265  1.0081
#                      Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  Random Forest Regressor  0.0348  0.0017  0.0413 -2.0907  0.0312  1.109
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0017   0.0017
# R-squared.........:  -0.0431  -2.0907
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (968, 73)
# 4        Transformed data shape         (968, 73)
# 5   Transformed train set shape         (774, 73)
# 6    Transformed test set shape         (194, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              fa62
#                       Model     MAE     MSE   RMSE      R2   RMSLE    MAPE  \
# rf  Random Forest Regressor  0.0172  0.0021  0.041  0.8094  0.0314  0.5045
#
#     TT (Sec)
# rf     0.234
#                      Model     MAE     MSE    RMSE      R2  RMSLE     MAPE
# 0  Random Forest Regressor  0.0818  0.0079  0.0888 -2.0005  0.062  26.0267
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.1354  0.0241  0.1554 -9.9336  0.1272  4.0566
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0079   0.0241
# R-squared.........:  -2.0005  -9.9336
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (938, 73)
# 4        Transformed data shape         (938, 73)
# 5   Transformed train set shape         (750, 73)
# 6    Transformed test set shape         (188, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              c88e
#                                     Model     MAE     MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.0217  0.0019  0.0414  0.7733
#
#            RMSLE    MAPE  TT (Sec)
# lightgbm  0.0309  1.7836    81.851
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0456  0.0033  0.0577 -0.0225  0.0408  1.2358
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0836  0.0085  0.0922 -2.7319  0.0719  0.8371
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0033   0.0085
# R-squared.........:  -0.0225  -2.7319
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1336, 73)
# 4        Transformed data shape        (1336, 73)
# 5   Transformed train set shape        (1068, 73)
# 6    Transformed test set shape         (268, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              290b
#                                     Model     MAE     MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.0131  0.0007  0.0258  0.8484
#
#            RMSLE     MAPE  TT (Sec)
# lightgbm  0.0193  15.5774    92.172
#                              Model     MAE     MSE    RMSE     R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0321  0.0024  0.0486 -0.491  0.0236  0.9909
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0363  0.0018  0.0419 -2.1853  0.0318  1.1452
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0024   0.0018
# R-squared.........:  -0.4910  -2.1853
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (968, 73)
# 4        Transformed data shape         (968, 73)
# 5   Transformed train set shape         (774, 73)
# 6    Transformed test set shape         (194, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              55aa
#                                     Model     MAE    MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.0176  0.002  0.0389  0.8288
#
#           RMSLE    MAPE  TT (Sec)
# lightgbm   0.03  0.4368    89.865
#                              Model     MAE    MSE    RMSE      R2   RMSLE     MAPE
# 0  Light Gradient Boosting Machine  0.0767  0.007  0.0836 -1.6587  0.0575  18.9803
#                              Model    MAE     MSE    RMSE       R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.144  0.0286  0.1691 -11.9473  0.1376  4.1869
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0070   0.0286
# R-squared.........:  -1.6587 -11.9473
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (938, 73)
# 4        Transformed data shape         (938, 73)
# 5   Transformed train set shape         (750, 73)
# 6    Transformed test set shape         (188, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              2648
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# knn  K Neighbors Regressor  0.0257  0.0025  0.0489  0.6896  0.0355  1.6267
#
#      TT (Sec)
# knn     0.056
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  K Neighbors Regressor  0.1215  0.0175  0.1323 -4.3794  0.1195  4.3383
#                    Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  K Neighbors Regressor  0.0639  0.0063  0.0795 -1.7729  0.0599  0.614
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0175   0.0063
# R-squared.........:  -4.3794  -1.7729
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1336, 73)
# 4        Transformed data shape        (1336, 73)
# 5   Transformed train set shape        (1068, 73)
# 6    Transformed test set shape         (268, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              e7f7
#                      Model    MAE     MSE    RMSE      R2   RMSLE     MAPE  \
# knn  K Neighbors Regressor  0.015  0.0008  0.0279  0.8234  0.0219  10.5787
#
#      TT (Sec)
# knn     0.177
#                    Model     MAE     MSE    RMSE     R2  RMSLE    MAPE
# 0  K Neighbors Regressor  0.0293  0.0016  0.0399 -0.008  0.028  1.0415
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  K Neighbors Regressor  0.0344  0.0017  0.0408 -2.0206  0.0302  1.0258
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0016   0.0017
# R-squared.........:  -0.0080  -2.0206
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (968, 73)
# 4        Transformed data shape         (968, 73)
# 5   Transformed train set shape         (774, 73)
# 6    Transformed test set shape         (194, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              2ca0
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# knn  K Neighbors Regressor  0.0266  0.0034  0.0532  0.6815  0.0423  0.9407
#
#      TT (Sec)
# knn      0.02
#                    Model     MAE     MSE    RMSE      R2   RMSLE       MAPE
# 0  K Neighbors Regressor  0.0971  0.0115  0.1072 -3.3716  0.0785  34.301102
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  K Neighbors Regressor  0.0652  0.0081  0.0901 -2.6736  0.0529  2.9432
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0115   0.0081
# R-squared.........:  -3.3716  -2.6736
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (938, 73)
# 4        Transformed data shape         (938, 73)
# 5   Transformed train set shape         (750, 73)
# 6    Transformed test set shape         (188, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              5b6f
#                            Model     MAE     MSE    RMSE      R2   RMSLE  \
# gbr  Gradient Boosting Regressor  0.0239  0.0023  0.0455  0.7271  0.0314
#
#        MAPE  TT (Sec)
# gbr  2.6916     0.169
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0458  0.0026  0.0506  0.2144  0.0405  1.2812
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0848  0.0083  0.0909 -2.6205  0.0779  0.8467
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0026   0.0083
# R-squared.........:   0.2144  -2.6205
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1336, 73)
# 4        Transformed data shape        (1336, 73)
# 5   Transformed train set shape        (1068, 73)
# 6    Transformed test set shape         (268, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              f48a
#                            Model     MAE     MSE    RMSE      R2   RMSLE  \
# gbr  Gradient Boosting Regressor  0.0149  0.0007  0.0257  0.8537  0.0209
#
#         MAPE  TT (Sec)
# gbr  15.7739     0.234
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0285  0.0015  0.0391  0.0342  0.0286  1.0583
#                          Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  Gradient Boosting Regressor  0.0302  0.0012  0.0347 -1.1857  0.0268  0.883
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0015   0.0012
# R-squared.........:   0.0342  -1.1857
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (968, 73)
# 4        Transformed data shape         (968, 73)
# 5   Transformed train set shape         (774, 73)
# 6    Transformed test set shape         (194, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              66ff
#                            Model     MAE     MSE    RMSE      R2   RMSLE  \
# gbr  Gradient Boosting Regressor  0.0205  0.0025  0.0436  0.7765  0.0332
#
#        MAPE  TT (Sec)
# gbr  1.2913     0.168
#                          Model     MAE     MSE    RMSE      R2   RMSLE     MAPE
# 0  Gradient Boosting Regressor  0.0847  0.0098  0.0988 -2.7146  0.0715  24.6865
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.1314  0.0233  0.1525 -9.5285  0.1234  4.1608
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0098   0.0233
# R-squared.........:  -2.7146  -9.5285
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (938, 73)
# 4        Transformed data shape         (938, 73)
# 5   Transformed train set shape         (750, 73)
# 6    Transformed test set shape         (188, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              2aff
#                  Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# huber  Huber Regressor  0.0331  0.0032  0.0544  0.6055  0.0397  1.9917
#
#        TT (Sec)
# huber     0.025
#              Model     MAE     MSE   RMSE     R2  RMSLE    MAPE
# 0  Huber Regressor  0.1169  0.0149  0.122 -3.576  0.111  3.9899
#              Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  Huber Regressor  0.0593  0.005  0.0711 -1.2146  0.0604  0.6608
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0149   0.0050
# R-squared.........:  -3.5760  -1.2146
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1336, 73)
# 4        Transformed data shape        (1336, 73)
# 5   Transformed train set shape        (1068, 73)
# 6    Transformed test set shape         (268, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              5534
#                  Model     MAE     MSE    RMSE      R2   RMSLE     MAPE  \
# huber  Huber Regressor  0.0208  0.0011  0.0321  0.7657  0.0252  17.6392
#
#        TT (Sec)
# huber     0.031
#              Model     MAE     MSE   RMSE      R2   RMSLE    MAPE
# 0  Huber Regressor  0.1113  0.0147  0.121 -8.2545  0.0906  4.7658
#              Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
# 0  Huber Regressor  0.0756  0.0074  0.0861 -12.4496  0.0767  1.7638
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0147   0.0074
# R-squared.........:  -8.2545 -12.4496
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (968, 73)
# 4        Transformed data shape         (968, 73)
# 5   Transformed train set shape         (774, 73)
# 6    Transformed test set shape         (194, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              7e5d
#                  Model     MAE     MSE   RMSE      R2   RMSLE    MAPE  \
# huber  Huber Regressor  0.0312  0.0039  0.057  0.6399  0.0424  1.4633
#
#        TT (Sec)
# huber     0.026
#              Model     MAE    MSE    RMSE       R2   RMSLE     MAPE
# 0  Huber Regressor  0.2498  0.097  0.3114 -35.8757  0.2038  31.8891
#              Model     MAE     MSE    RMSE       R2   RMSLE    MAPE
# 0  Huber Regressor  0.2079  0.0699  0.2644 -30.6555  0.1566  6.9294
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0970   0.0699
# R-squared.........: -35.8757 -30.6555
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (938, 73)
# 4        Transformed data shape         (938, 73)
# 5   Transformed train set shape         (750, 73)
# 6    Transformed test set shape         (188, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              1435
#                   Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# ada  AdaBoost Regressor  0.0491  0.0044  0.0654  0.4339  0.0519  1.9804
#
#      TT (Sec)
# ada     0.057
#                 Model     MAE    MSE   RMSE     R2  RMSLE    MAPE
# 0  AdaBoost Regressor  0.0579  0.004  0.063 -0.221  0.058  1.7633
#                 Model    MAE     MSE   RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.068  0.0058  0.076 -1.5326  0.0682  0.6635
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0040   0.0058
# R-squared.........:  -0.2210  -1.5326
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1336, 73)
# 4        Transformed data shape        (1336, 73)
# 5   Transformed train set shape        (1068, 73)
# 6    Transformed test set shape         (268, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              0a7b
#                   Model     MAE    MSE    RMSE     R2   RMSLE     MAPE  \
# ada  AdaBoost Regressor  0.0222  0.001  0.0313  0.785  0.0269  15.0553
#
#      TT (Sec)
# ada     0.075
#                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.0305  0.0014  0.0374  0.1158  0.0337  0.8703
#                 Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  AdaBoost Regressor  0.0554  0.0035  0.0589 -5.3101  0.0494  1.432
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0014   0.0035
# R-squared.........:   0.1158  -5.3101
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (968, 73)
# 4        Transformed data shape         (968, 73)
# 5   Transformed train set shape         (774, 73)
# 6    Transformed test set shape         (194, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              71ca
#                   Model     MAE    MSE    RMSE      R2   RMSLE    MAPE  \
# ada  AdaBoost Regressor  0.0333  0.003  0.0509  0.7095  0.0398  2.2805
#
#      TT (Sec)
# ada     0.057
#                 Model     MAE     MSE   RMSE      R2   RMSLE     MAPE
# 0  AdaBoost Regressor  0.0883  0.0094  0.097 -2.5781  0.0694  28.2232
#                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.1076  0.0138  0.1174 -5.2412  0.0929  3.4317
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0094   0.0138
# R-squared.........:  -2.5781  -5.2412
#
#
#
#  CLUSTER NUMBER: -1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (938, 73)
# 4        Transformed data shape         (938, 73)
# 5   Transformed train set shape         (750, 73)
# 6    Transformed test set shape         (188, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              4a8c
#                            Model    MAE     MSE    RMSE      R2   RMSLE  \
# omp  Orthogonal Matching Pursuit  0.048  0.0045  0.0653  0.4538  0.0482
#
#        MAPE  TT (Sec)
# omp  2.0081      0.02
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.0866  0.0089  0.0946 -1.7481  0.0849  2.7589
#                          Model     MAE   MSE    RMSE      R2  RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.0854  0.01  0.1001 -3.3923  0.077  0.8245
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0089   0.0100
# R-squared.........:  -1.7481  -3.3923
#
#
#
#  CLUSTER NUMBER:  0
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape        (1336, 73)
# 4        Transformed data shape        (1336, 73)
# 5   Transformed train set shape        (1068, 73)
# 6    Transformed test set shape         (268, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              e9d7
#                            Model    MAE     MSE    RMSE      R2   RMSLE  \
# omp  Orthogonal Matching Pursuit  0.026  0.0014  0.0372  0.6949  0.0307
#
#         MAPE  TT (Sec)
# omp  21.9847     0.024
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.0513  0.0041  0.0642 -1.6013  0.0396  2.3754
#                          Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  Orthogonal Matching Pursuit  0.0295  0.0013  0.0363 -1.3938  0.0336  0.769
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0041   0.0013
# R-squared.........:  -1.6013  -1.3938
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 3M
# 2                   Target type        Regression
# 3           Original data shape         (968, 73)
# 4        Transformed data shape         (968, 73)
# 5   Transformed train set shape         (774, 73)
# 6    Transformed test set shape         (194, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              3735
#                            Model     MAE     MSE    RMSE      R2   RMSLE  \
# omp  Orthogonal Matching Pursuit  0.0425  0.0039  0.0603  0.5873  0.0476
#
#        MAPE  TT (Sec)
# omp  3.2152     0.021
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.0472  0.0042  0.0646 -0.5884  0.0453  9.9541
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.1023  0.0147  0.1213 -5.6658  0.0849  2.1964
#
#                           1M       2M       3M
#
#                           1M       2M       3M
# Mean Squared Error:   0.0042   0.0147
# R-squared.........:  -0.5884  -5.6658

# %% [markdown]
# # 1M

# %% [markdown]
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              f5a7
#                 Model    MAE     MSE    RMSE      R2   RMSLE    MAPE  TT (Sec)
# lr  Linear Regression  0.035  0.0023  0.0479  0.4352  0.0384  2.3951     0.384
#                Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Linear Regression  0.0538  0.0072  0.0849 -0.5293  0.0423  1.4211
#                Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Linear Regression  0.0304  0.0019  0.0435 -2.1111  0.0342  4.2224
#
#                           1M       2M       3M
# Mean Squared Error:   0.0072   0.0019
# R-squared.........:  -0.5293  -2.1111
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              691b
#                   Model    MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# ridge  Ridge Regression  0.035  0.0023  0.0479  0.4364  0.0383  2.3917
#
#        TT (Sec)
# ridge     0.252
#               Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Ridge Regression  0.0519  0.0071  0.0843 -0.5097  0.0418  1.2807
#               Model     MAE     MSE    RMSE    R2   RMSLE    MAPE
# 0  Ridge Regression  0.0294  0.0018  0.0424 -1.96  0.0332  3.5801
#
#                           1M       2M       3M
# Mean Squared Error:   0.0071   0.0018
# R-squared.........:  -0.5097  -1.9600
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              49e7
#                     Model     MAE    MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0121  0.001  0.0305  0.7656  0.0227  0.7528
#
#     TT (Sec)
# et       0.5
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0652  0.0058  0.0761 -0.2303  0.0581  1.9638
#                    Model     MAE     MSE    RMSE      R2  RMSLE    MAPE
# 0  Extra Trees Regressor  0.0442  0.0028  0.0525 -3.5334  0.024  4.1196
#
#                           1M       2M       3M
# Mean Squared Error:   0.0058   0.0028
# R-squared.........:  -0.2303  -3.5334
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              455a
#                       Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# rf  Random Forest Regressor  0.0136  0.0011  0.0318  0.7467  0.0237  0.8467
#
#     TT (Sec)
# rf      1.86
#                      Model     MAE     MSE   RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0688  0.0062  0.079 -0.3268  0.0628  2.0894
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0541  0.0042  0.0647 -5.8759  0.0256  3.4559
#
#                           1M       2M       3M
# Mean Squared Error:   0.0062   0.0042
# R-squared.........:  -0.3268  -5.8759
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              0922
#                                     Model     MAE    MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.0148  0.001  0.0311  0.7604
#
#            RMSLE    MAPE  TT (Sec)
# lightgbm  0.0237  1.0852    98.423
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0647  0.0063  0.0792 -0.3308  0.0614  2.1136
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0539  0.0043  0.0658 -6.1143  0.0269  3.9759
#
#                           1M       2M       3M
# Mean Squared Error:   0.0063   0.0043
# R-squared.........:  -0.3308  -6.1143
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              a421
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# knn  K Neighbors Regressor  0.0179  0.0014  0.0364  0.6704  0.0262  1.2445
#
#      TT (Sec)
# knn     0.145
#                    Model     MAE     MSE    RMSE     R2   RMSLE    MAPE
# 0  K Neighbors Regressor  0.0689  0.0086  0.0928 -0.827  0.0471  1.3586
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  K Neighbors Regressor  0.0336  0.0015  0.0393 -1.5432  0.0285  4.1693
#
#                           1M       2M       3M
# Mean Squared Error:   0.0086   0.0015
# R-squared.........:  -0.8270  -1.5432
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              b3bd
#                            Model     MAE     MSE    RMSE      R2   RMSLE  \
# gbr  Gradient Boosting Regressor  0.0219  0.0014  0.0369  0.6631  0.0293
#
#        MAPE  TT (Sec)
# gbr  1.3654     1.145
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0568  0.0045  0.0669  0.0494  0.0503  1.5523
#                          Model     MAE     MSE    RMSE     R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.0351  0.0021  0.0463 -2.526  0.0264  5.7936
#
#                           1M       2M       3M
# Mean Squared Error:   0.0045   0.0021
# R-squared.........:   0.0494  -2.5260
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              cce5
#                  Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# huber  Huber Regressor  0.0334  0.0025  0.0494  0.4001  0.0377  2.4105
#
#        TT (Sec)
# huber     0.157
#              Model     MAE     MSE  RMSE      R2   RMSLE    MAPE
# 0  Huber Regressor  0.0605  0.0081  0.09 -0.7192  0.0423  1.5453
#              Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  Huber Regressor  0.0303  0.002  0.0443 -2.2303  0.0323  3.4169
#
#                           1M       2M       3M
# Mean Squared Error:   0.0081   0.0020
# R-squared.........:  -0.7192  -2.2303
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              c3f3
#                   Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# ada  AdaBoost Regressor  0.0471  0.0037  0.0605  0.0987  0.0466  2.3654
#
#      TT (Sec)
# ada     0.297
#                 Model     MAE     MSE   RMSE     R2   RMSLE   MAPE
# 0  AdaBoost Regressor  0.0669  0.0056  0.075 -0.196  0.0482  1.749
#                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.0429  0.0025  0.0502 -3.1433  0.0208  3.9924
#
#                           1M       2M       3M
# Mean Squared Error:   0.0056   0.0025
# R-squared.........:  -0.1960  -3.1433
#
#
#
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 1M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              15a5
#                            Model     MAE     MSE    RMSE      R2   RMSLE  \
# omp  Orthogonal Matching Pursuit  0.0436  0.0032  0.0562  0.2248  0.0445
#
#        MAPE  TT (Sec)
# omp  2.6211     0.126
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.0681  0.0055  0.0741 -0.1674  0.0505  2.3892
#                          Model     MAE     MSE   RMSE      R2  RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.0442  0.0028  0.053 -3.6124  0.021  5.8412
#
#                           1M       2M       3M
# Mean Squared Error:   0.0055   0.0028
# R-squared.........:  -0.1674  -3.6124

# %%
# 6M

# %%
 	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC	TT (Sec)
lightgbm	Light Gradient Boosting Machine	0.9218	0.9855	0.9218	0.9225	0.9217	0.8818	0.8822	475.7920
rf	Random Forest Classifier	0.9160	0.9850	0.9160	0.9170	0.9161	0.8731	0.8735	0.2760
et	Extra Trees Classifier	0.9142	0.9851	0.9142	0.9150	0.9142	0.8704	0.8708	0.1670
gbc	Gradient Boosting Classifier	0.8903	0.0000	0.8903	0.8910	0.8901	0.8344	0.8349	2.7670
qda	Quadratic Discriminant Analysis	0.8627	0.0000	0.8627	0.8638	0.8627	0.7928	0.7933	0.1300
knn	K Neighbors Classifier	0.8599	0.9560	0.8599	0.8634	0.8598	0.7881	0.7898	0.3050
dt	Decision Tree Classifier	0.8436	0.8812	0.8436	0.8445	0.8436	0.7636	0.7640	0.1590
lr	Logistic Regression	0.8081	0.0000	0.8081	0.8083	0.8074	0.7105	0.7112	0.4540
ridge	Ridge Classifier	0.7965	0.0000	0.7965	0.7977	0.7955	0.6939	0.6954	0.1290
lda	Linear Discriminant Analysis	0.7892	0.0000	0.7892	0.7902	0.7884	0.6828	0.6840	0.1350
svm	SVM - Linear Kernel	0.7472	0.0000	0.7472	0.7483	0.7469	0.6187	0.6194	0.1380
ada	Ada Boost Classifier	0.7457	0.0000	0.7457	0.7489	0.7462	0.6157	0.6167	0.2970
nb	Naive Bayes	0.5408	0.7215	0.5408	0.5552	0.5382	0.3023	0.3076	0.1280
dummy	Dummy Classifier	0.3770	0.5000	0.3770	0.1421	0.2064	0.0000	0.0000	0.1690

# %%
# SEM TUNED

Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
Fold	 	 	 	 	 	 	 
0	0.9246	0.9895	0.9246	0.9250	0.9243	0.8868	0.8873
1	0.9121	0.9898	0.9121	0.9131	0.9122	0.8677	0.8680
2	0.9447	0.9928	0.9447	0.9450	0.9448	0.9168	0.9169
3	0.8945	0.9817	0.8945	0.8948	0.8941	0.8416	0.8421
4	0.9296	0.9887	0.9296	0.9302	0.9297	0.8941	0.8943
5	0.9472	0.9933	0.9472	0.9475	0.9473	0.9206	0.9207
6	0.9471	0.9911	0.9471	0.9472	0.9469	0.9205	0.9208
7	0.9320	0.9885	0.9320	0.9329	0.9316	0.8979	0.8987
8	0.9219	0.9848	0.9219	0.9220	0.9219	0.8825	0.8826
9	0.8967	0.9802	0.8967	0.8963	0.8961	0.8449	0.8453
Mean	0.9250	0.9880	0.9250	0.9254	0.9249	0.8874	0.8877
Std	0.0183	0.0042	0.0183	0.0184	0.0184	0.0275	0.0274


 	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
0	Light Gradient Boosting Machine	0.4438	0.5682	0.4438	0.5793	0.4309	0.1164	0.1368array([[ 66,  23,   0],
       [119,  90,   2],
       [ 32,  27,   6]])


Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
0	Light Gradient Boosting Machine	0.3452	0.5206	0.3452	0.4442	0.3296	0.0206	0.0237array([[ 70,  31,   0],
       [143,  25,   1],
       [ 10,  54,  31]])

## Finalized


Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
0	Light Gradient Boosting Machine	0.3945	0.5858	0.3945	0.5442	0.3861	0.0652	0.0797array([[ 65,  24,   0],
       [141,  68,   2],
       [ 25,  29,  11]])

 	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
0	Light Gradient Boosting Machine	0.3507	0.5225	0.3507	0.5058	0.3418	0.0475	0.0594array(
    [[ 68,  33,   0],
       [138,  31,   0],
       [ 46,  20,  29]])

# %% [markdown]
#  CLUSTER NUMBER:  1
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              d0be
#                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# lr  Linear Regression  0.0489  0.0046  0.0677  0.7942  0.0528  1.5318
#
#     TT (Sec)
# lr     0.402
#                Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  Linear Regression  0.0715  0.0098  0.0989 -0.1434  0.0814  1.048
#                Model     MAE    MSE    RMSE      R2   RMSLE    MAPE
# 0  Linear Regression  0.1337  0.021  0.1448 -0.9495  0.0868  4.3478
#
#                           1M       2M       3M
# Mean Squared Error:   0.0098   0.0210
# R-squared.........:  -0.1434  -0.9495
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              dd8d
#                   Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# ridge  Ridge Regression  0.0489  0.0046  0.0677  0.7946  0.0528  1.5262
#
#        TT (Sec)
# ridge     0.251
#               Model     MAE     MSE    RMSE      R2  RMSLE   MAPE
# 0  Ridge Regression  0.0686  0.0095  0.0972 -0.1047   0.08  0.976
#               Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  Ridge Regression  0.1312  0.0201  0.1418 -0.8707  0.0846  4.242
#
#                           1M       2M       3M
# Mean Squared Error:   0.0095   0.0201
# R-squared.........:  -0.1047  -0.8707
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              99a0
#                     Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# et  Extra Trees Regressor  0.0163  0.0014  0.0373  0.9361  0.0272  0.5262
#
#     TT (Sec)
# et     0.479
#                    Model     MAE     MSE    RMSE     R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.0422  0.0059  0.0768  0.311  0.0628  0.5623
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Extra Trees Regressor  0.1284  0.0193  0.1388 -0.7916  0.0645  3.6016
#
#                           1M       2M       3M
# Mean Squared Error:   0.0059   0.0193
# R-squared.........:   0.3110  -0.7916
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              e6ed
#                       Model     MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# rf  Random Forest Regressor  0.0189  0.0017  0.0408  0.9235  0.0292  0.6492
#
#     TT (Sec)
# rf     1.651
#                      Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Random Forest Regressor  0.0455  0.0061  0.0782  0.2848  0.0675  0.5775
#                      Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  Random Forest Regressor  0.1382  0.0219  0.1479 -1.0356  0.0686  3.837
#
#                           1M       2M       3M
# Mean Squared Error:   0.0061   0.0219
# R-squared.........:   0.2848  -1.0356
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              4f48
#                                     Model   MAE     MSE    RMSE      R2  \
# lightgbm  Light Gradient Boosting Machine  0.02  0.0016  0.0395  0.9282
#
#            RMSLE    MAPE  TT (Sec)
# lightgbm  0.0283  0.7707    96.026
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.0506  0.0078  0.0885  0.0852  0.0593  0.7555
#                              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Light Gradient Boosting Machine  0.1426  0.0227  0.1505 -1.1084  0.0716  3.8872
#
#                           1M       2M       3M
# Mean Squared Error:   0.0078   0.0227
# R-squared.........:   0.0852  -1.1084
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              5cb2
#                      Model    MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# knn  K Neighbors Regressor  0.025  0.0023  0.0476  0.8969  0.0355  0.9952
#
#      TT (Sec)
# knn     0.145
#                    Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  K Neighbors Regressor  0.0435  0.0053  0.0729  0.3794  0.0619  0.8357
#                    Model     MAE     MSE  RMSE      R2   RMSLE    MAPE
# 0  K Neighbors Regressor  0.1223  0.0169  0.13 -0.5712  0.0623  3.4926
#
#                           1M       2M       3M
# Mean Squared Error:   0.0053   0.0169
# R-squared.........:   0.3794  -0.5712
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              0775
#                            Model     MAE     MSE    RMSE      R2   RMSLE  \
# gbr  Gradient Boosting Regressor  0.0286  0.0022  0.0468  0.9012  0.0336
#
#        MAPE  TT (Sec)
# gbr  1.0921     1.148
#                          Model     MAE     MSE    RMSE      R2   RMSLE   MAPE
# 0  Gradient Boosting Regressor  0.0489  0.0072  0.0847  0.1623  0.0579  0.787
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Gradient Boosting Regressor  0.1194  0.0167  0.1291 -0.5512  0.0551  3.3548
#
#                           1M       2M       3M
# Mean Squared Error:   0.0072   0.0167
# R-squared.........:   0.1623  -0.5512
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              a91b
#                  Model     MAE    MSE    RMSE      R2   RMSLE    MAPE  \
# huber  Huber Regressor  0.0464  0.005  0.0703  0.7781  0.0544  1.3458
#
#        TT (Sec)
# huber     0.147
#              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Huber Regressor  0.0696  0.0111  0.1053 -0.2971  0.0761  0.9509
#              Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Huber Regressor  0.1331  0.0209  0.1445 -0.9437  0.0824  4.1231
#
#                           1M       2M       3M
# Mean Squared Error:   0.0111   0.0209
# R-squared.........:  -0.2971  -0.9437
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              3e87
#                   Model    MAE     MSE    RMSE      R2   RMSLE    MAPE  \
# ada  AdaBoost Regressor  0.063  0.0062  0.0787  0.7215  0.0651  1.3629
#
#      TT (Sec)
# ada     0.311
#                 Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  AdaBoost Regressor  0.0541  0.0062  0.0789  0.2726  0.0694  0.5812
#                 Model     MAE     MSE    RMSE      R2  RMSLE    MAPE
# 0  AdaBoost Regressor  0.0883  0.0094  0.0972  0.1209  0.066  2.0374
#
#                           1M       2M       3M
# Mean Squared Error:   0.0062   0.0094
# R-squared.........:   0.2726   0.1209
#
#
#                     Description             Value
# 0                    Session id               123
# 1                        Target  Rentabilidade 6M
# 2                   Target type        Regression
# 3           Original data shape        (4970, 73)
# 4        Transformed data shape        (4970, 73)
# 5   Transformed train set shape        (3976, 73)
# 6    Transformed test set shape         (994, 73)
# 7              Numeric features                72
# 8                    Preprocess              True
# 9               Imputation type            simple
# 10           Numeric imputation              mean
# 11       Categorical imputation              mode
# 12               Transformation              True
# 13        Transformation method          quantile
# 14               Fold Generator             KFold
# 15                  Fold Number                10
# 16                     CPU Jobs                -1
# 17                      Use GPU             False
# 18               Log Experiment             False
# 19              Experiment Name  reg-default-name
# 20                          USI              a7bf
#                            Model     MAE     MSE    RMSE     R2   RMSLE  \
# omp  Orthogonal Matching Pursuit  0.0601  0.0067  0.0816  0.701  0.0603
#
#        MAPE  TT (Sec)
# omp  2.0102     0.124
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.0639  0.0082  0.0908  0.0364  0.0792  1.3934
#                          Model     MAE     MSE    RMSE      R2   RMSLE    MAPE
# 0  Orthogonal Matching Pursuit  0.1231  0.0179  0.1337 -0.6637  0.0743  4.0061
#
#                           1M       2M       3M
# Mean Squared Error:   0.0082   0.0179
# R-squared.........:   0.0364  -0.6637
