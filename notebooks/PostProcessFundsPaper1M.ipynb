# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


def my_confusion2(Classifier, confusion_matrix, data_type):
    # Normalize the confusion matrix
    row_sums = confusion_matrix.sum(axis=1, keepdims=True)
    normalized_confusion_matrix = confusion_matrix / row_sums * 100  # Convert to percentages

    # Increase font sizes
    plt.rcParams.update({'font.size': 18})
    plt.rcParams.update({'axes.titlesize': 22, 'axes.labelsize': 20, 'xtick.labelsize': 18, 'ytick.labelsize': 18})

    # Create annotations with both raw data and percentages
    annotations = np.empty_like(confusion_matrix).astype(str)
    for i in range(confusion_matrix.shape[0]):
        for j in range(confusion_matrix.shape[1]):
            annotations[i, j] = f'{confusion_matrix[i, j]}\n({normalized_confusion_matrix[i, j]:.2f}%)'

    # Plotting the confusion matrix with both raw data and normalized data
    plt.figure(figsize=(8, 6))
    sns.heatmap(normalized_confusion_matrix , annot=annotations, fmt="", cmap="BuPu", cbar=False, 
                xticklabels=['0', '1', '2'],
                yticklabels=['0', '1', '2'],
                annot_kws={"size": 20})

    plt.xlabel('Predicted Class', fontsize=20)
    plt.ylabel('True Class', fontsize=20)
    # plt.title(f'{Classifier} Confusion Matrix {data_type}', fontsize=20)
    plt.savefig(f'{Classifier} Confusion Matrix {data_type}_1M.pdf', format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.show()

# %%
#  	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Light Gradient Boosting Machine	0.5726	0.6858	0.5726	0.5374	0.5397	0.2519	0.2639array([[ 23,  87,   0],
#        [ 10, 158,  18],
#        [ 38,   3,  28]])


#  	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.5205	0.6923	0.5205	0.5128	0.5074	0.2103	0.2142array([[ 29,  81,   0],
#        [  7, 125,  54],
#        [ 30,   3,  36]])


#  	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Extra Trees Classifier	0.6164	0.7201	0.6164	0.5870	0.5703	0.3108	0.3406array([[ 19,  91,   0],
#        [  5, 175,   6],
#        [ 35,   3,  31]])




#  	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Light Gradient Boosting Machine	0.3589	0.5010	0.3589	0.2556	0.2951	-0.0366	-0.0391array([[  3,  64,  47],
#        [ 10, 127,  23],
#        [ 45,  45,   1]])


#  	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.3562	0.5408	0.3562	0.2959	0.3177	-0.0298	-0.0309array([[ 11,  62,  41],
#        [ 22, 112,  26],
#        [ 40,  44,   7]])



#  	Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Extra Trees Classifier	0.4274	0.5684	0.4274	0.2980	0.3347	0.0448	0.0523array([[  8,  81,  25],
#        [  8, 145,   7],
#        [ 41,  47,   3]])

# %% [markdown]
# ## primeiro mês

# %%
Classifier = 'LGBMClassifier'
data_type = 'on Unseen Data 1'
# Given confusion matrix
confusion_matrix = np.array([[ 23,  87,   0],
[ 10, 158,  18],
[ 38,   3,  28]])

my_confusion2(Classifier, confusion_matrix, data_type)

# %%
Classifier = 'RFClassifier'
data_type = 'on Unseen Data 1'

# Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.3973	0.5899	0.3973	0.4910	0.3687	0.0728	0.0888
# array([[ 76,  13,   0],
#        [150,  57,   4],
#        [  4,  49,  12]])

# Given confusion matrix
confusion_matrix = np.array([[ 29,  81,   0],
[  7, 125,  54],
[ 30,   3,  36]
])

my_confusion2(Classifier, confusion_matrix, data_type)

# %%
Classifier = 'ETClassifier'
data_type = 'on Unseen Data 1'

# Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Extra Trees Classifier	0.4027	0.6726	0.4027	0.5591	0.3887	0.1030	0.1326
# array([[ 73,  16,   0],
#        [148,  60,   3],
#        [ 25,  26,  14]])

# Given confusion matrix
confusion_matrix = np.array([[ 19,  91,   0],
[  5, 175,   6],
[ 35,   3,  31]])

my_confusion2(Classifier, confusion_matrix, data_type)

# %% [markdown]
# ## Segundo mes

# %%
Classifier = 'LGBMClassifier'
data_type = 'on Unseen Data 2'

# Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.3973	0.5899	0.3973	0.4910	0.3687	0.0728	0.0888
# array([[ 76,  13,   0],
#        [150,  57,   4],
#        [  4,  49,  12]])

# Given confusion matrix
confusion_matrix = np.array([[  3,  64,  47],
[ 10, 127,  23],
[ 45,  45,   1]])

my_confusion2(Classifier, confusion_matrix, data_type)

# %%
Classifier = 'RFClassifier'
data_type = 'on Unseen Data 2'

# Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.3973	0.5899	0.3973	0.4910	0.3687	0.0728	0.0888
# array([[ 76,  13,   0],
#        [150,  57,   4],
#        [  4,  49,  12]])

# Given confusion matrix
confusion_matrix = np.array([[ 11,  62,  41],
[ 22, 112,  26],
[ 40,  44,   7]])   

my_confusion2(Classifier, confusion_matrix, data_type)

# %%
Classifier = 'ETClassifier'
data_type = 'on Unseen Data 2'

# Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.3973	0.5899	0.3973	0.4910	0.3687	0.0728	0.0888
# array([[ 76,  13,   0],
#        [150,  57,   4],
#        [  4,  49,  12]])

# Given confusion matrix
confusion_matrix = np.array([ [  8,  81,  25],
 [  8, 145,   7],
 [ 41,  47,   3]])

my_confusion2(Classifier, confusion_matrix, data_type)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np


def my_confusion3(Classifier, confusion_matrix, data_type):
    # Normalize the confusion matrix
    row_sums = confusion_matrix.sum(axis=1, keepdims=True)
    normalized_confusion_matrix = confusion_matrix / row_sums * 100  # Convert to percentages
    
    # Calculate accuracy
    accuracy = np.trace(confusion_matrix) / np.sum(confusion_matrix)

    # Increase font sizes
    plt.rcParams.update({'font.size': 18})
    plt.rcParams.update({'axes.titlesize': 22, 'axes.labelsize': 20, 'xtick.labelsize': 18, 'ytick.labelsize': 18})

    # Create annotations with both raw data and percentages
    annotations = np.empty_like(confusion_matrix).astype(str)
    for i in range(confusion_matrix.shape[0]):
        for j in range(confusion_matrix.shape[1]):
            annotations[i, j] = f'{confusion_matrix[i, j]}\n({normalized_confusion_matrix[i, j]:.2f}%)'

    # Plotting the confusion matrix with both raw data and normalized data
    plt.figure(figsize=(8, 6))
    sns.heatmap(normalized_confusion_matrix , annot=annotations, fmt="", cmap="Reds", cbar=False, 
                xticklabels=['0', '1', '2'],
                yticklabels=['0', '1', '2'],
                annot_kws={"size": 20})

    plt.xlabel('Predicted Class', fontsize=20)
    plt.ylabel('True Class', fontsize=20)
    # plt.title(f'{Classifier} Confusion Matrix {data_type}', fontsize=20)
    plt.savefig(f'{Classifier} Confusion Matrix {data_type}_1M.pdf', format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)
    plt.show()

# %%
Classifier = 'LGBMClassifier'
data_type = 'on Test Data'

# Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.3973	0.5899	0.3973	0.4910	0.3687	0.0728	0.0888
# array([[ 76,  13,   0],
#        [150,  57,   4],
#        [  4,  49,  12]])

# Given confusion matrix
confusion_matrix = np.array([[309,23, 4],
[23,338,14],
[11,24,248 ]])


my_confusion3(Classifier, confusion_matrix, data_type)

# %%
Classifier = 'RFClassifier'
data_type = 'on Test Data'

# Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.3973	0.5899	0.3973	0.4910	0.3687	0.0728	0.0888
# array([[ 76,  13,   0],
#        [150,  57,   4],
#        [  4,  49,  12]])

# Given confusion matrix
confusion_matrix = np.array([[302,28,6],
[25,335,15],
[9,29,245]])


my_confusion3(Classifier, confusion_matrix, data_type)

# %%
Classifier = 'ETClassifier'
data_type = 'on Test Data'

# Model	Accuracy	AUC	Recall	Prec.	F1	Kappa	MCC
# 0	Random Forest Classifier	0.3973	0.5899	0.3973	0.4910	0.3687	0.0728	0.0888
# array([[ 76,  13,   0],
#        [150,  57,   4],
#        [  4,  49,  12]])

# Given confusion matrix
confusion_matrix = np.array([[305,27,4],
[22,340,13],
[8,30,245]])


my_confusion3(Classifier, confusion_matrix, data_type)

# %%
# %cd /media/eel/DATAUbuntu/Projetos/Pub2023-2024/PortModels/
import pandas as pd
#from functions import *
import ipywidgets as widgets
from ipywidgets import interact, fixed, interact_manual
# Evaluating the model
from sklearn.metrics import mean_squared_error, r2_score
from pycaret.classification import *
from sklearn.metrics import confusion_matrix
# Out:
# /media/eel/DATAUbuntu/Projetos/Pub2023-2024/PortModels

# %%
dta0_01 = pd.read_csv('data/raw/jan2023.csv')
dta0_02 = pd.read_csv('data/raw/fev2023.csv')
dta0_03 = pd.read_csv('data/raw/mar2023.csv')
dta0_04 = pd.read_csv('data/raw/abr2023.csv')
dta0_05 = pd.read_csv('data/raw/mai2023.csv')
dta0_06 = pd.read_csv('data/raw/jun2023.csv')
dta0_07 = pd.read_csv('data/raw/jul2023.csv')
dta0_08 = pd.read_csv('data/raw/ago2023.csv')
dta0_09 = pd.read_csv('data/raw/set2023.csv')
dta0_10 = pd.read_csv('data/raw/out2023.csv')
dta0_11 = pd.read_csv('data/raw/nov2023.csv')
data0_0 = pd.read_csv('data/raw/dez2023.csv')
data0_1 = pd.read_csv('data/raw/jan2024.csv')
data0_2 = pd.read_csv('data/raw/fev2024.csv')
data0_3 = pd.read_csv('data/raw/mar2024.csv')
data0_4 = pd.read_csv('data/raw/abr2024.csv')
data0_5 = pd.read_csv('data/raw/mai2024.csv')

feat_drop = ['Nome do fundo','CNPJ do fundo','cnpj', 'Classe N1',
        'Patrimônio líquido', 'Cotistas', 'Valor da cota', 'Variação da Cota',
        'Drawdown máximo']

feat_drop = ['Nome do fundo', 'cnpj', 'Classe N1',
        'Patrimônio líquido', 'Cotistas', 'Valor da cota', 'Variação da Cota',
        'Drawdown máximo']


feat_dropt = ['Nome do fundo','cnpj', 'Classe N1',
        'Patrimônio líquido', 'Cotistas', 'Valor da cota', 'Variação da Cota',
        'Drawdown máximo']

cpj01 = dta0_01['CNPJ do fundo'].loc[ (dta0_01['Cotistas'] > 100) & (dta0_01['Classe N1'] == 'Ações')].values
cpj02 = dta0_02['CNPJ do fundo'].loc[ (dta0_02['Cotistas'] > 100) & (dta0_02['Classe N1'] == 'Ações')].values
cpj03 = dta0_03['CNPJ do fundo'].loc[ (dta0_03['Cotistas'] > 100) & (dta0_03['Classe N1'] == 'Ações')].values
cpj04 = dta0_04['CNPJ do fundo'].loc[ (dta0_04['Cotistas'] > 100) & (dta0_04['Classe N1'] == 'Ações')].values
cpj05 = dta0_05['CNPJ do fundo'].loc[ (dta0_05['Cotistas'] > 100) & (dta0_05['Classe N1'] == 'Ações')].values     
cpj06 = dta0_06['CNPJ do fundo'].loc[ (dta0_06['Cotistas'] > 100) & (dta0_06['Classe N1'] == 'Ações')].values     
cpj07 = dta0_07['CNPJ do fundo'].loc[ (dta0_07['Cotistas'] > 100) & (dta0_07['Classe N1'] == 'Ações')].values        
cpj08 = dta0_08['CNPJ do fundo'].loc[ (dta0_08['Cotistas'] > 100) & (dta0_08['Classe N1'] == 'Ações')].values        
cpj09 = dta0_09['CNPJ do fundo'].loc[ (dta0_09['Cotistas'] > 100) & (dta0_09['Classe N1'] == 'Ações')].values        
cpj10 = dta0_10['CNPJ do fundo'].loc[ (dta0_10['Cotistas'] > 100) & (dta0_10['Classe N1'] == 'Ações')].values        
cpj11 = dta0_11['CNPJ do fundo'].loc[ (dta0_11['Cotistas'] > 100) & (dta0_11['Classe N1'] == 'Ações')].values
cnpj0 = data0_0['CNPJ do fundo'].loc[ (data0_0['Cotistas'] > 100) & (data0_0['Classe N1'] == 'Ações')].values
cnpj1 = data0_1['CNPJ do fundo'].loc[ (data0_1['Cotistas'] > 100) & (data0_1['Classe N1'] == 'Ações')].values
cnpj2 = data0_2['CNPJ do fundo'].loc[ (data0_2['Cotistas'] > 100) & (data0_2['Classe N1'] == 'Ações')].values
cnpj3 = data0_3['CNPJ do fundo'].loc[ (data0_3['Cotistas'] > 100) & (data0_3['Classe N1'] == 'Ações')].values
cnpj4 = data0_4['CNPJ do fundo'].loc[ (data0_4['Cotistas'] > 100) & (data0_4['Classe N1'] == 'Ações')].values
cnpj5 = data0_5['CNPJ do fundo'].loc[ (data0_5['Cotistas'] > 100) & (data0_5['Classe N1'] == 'Ações')].values

set1 = set(cpj01)
set2 = set(cpj02)
matches01 = list(set1.intersection(set2))
dta01  = dta0_01.loc[dta0_01['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_02.loc[dta0_02['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta01 = dta01.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cpj02)
set2 = set(cpj03)
matches01 = list(set1.intersection(set2))
dta02  = dta0_02.loc[dta0_02['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_03.loc[dta0_03['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta02 = dta02.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cpj03)
set2 = set(cpj04)
matches01 = list(set1.intersection(set2))
dta03  = dta0_03.loc[dta0_03['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_04.loc[dta0_04['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta03 = dta03.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cpj04)
set2 = set(cpj05)
matches01 = list(set1.intersection(set2))
dta04  = dta0_04.loc[dta0_04['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_05.loc[dta0_05['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta04 = dta04.merge(rent1M, how='inner', on='CNPJ do fundo')


set1 = set(cpj05)
set2 = set(cpj06)
matches01 = list(set1.intersection(set2))
dta05  = dta0_05.loc[dta0_05['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_06.loc[dta0_06['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta05 = dta05.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cpj06)
set2 = set(cpj07)
matches01 = list(set1.intersection(set2))
dta06  = dta0_06.loc[dta0_06['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_07.loc[dta0_07['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta06 = dta06.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cpj07)
set2 = set(cpj08)
matches01 = list(set1.intersection(set2))
dta07  = dta0_07.loc[dta0_07['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_08.loc[dta0_08['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta07 = dta07.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cpj08)
set2 = set(cpj09)
matches01 = list(set1.intersection(set2))
dta08  = dta0_08.loc[dta0_08['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_09.loc[dta0_09['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta08 = dta08.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cpj09)
set2 = set(cpj10)
matches01 = list(set1.intersection(set2))
dta09  = dta0_09.loc[dta0_09['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_10.loc[dta0_10['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta09 = dta09.merge(rent1M, how='inner', on='CNPJ do fundo')
                
set1 = set(cpj10)
set2 = set(cpj11)
matches01 = list(set1.intersection(set2))
dta10  = dta0_10.loc[dta0_10['CNPJ do fundo'].isin(matches01)]
rent1M = dta0_11.loc[dta0_11['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta10 = dta10.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cpj11)
set2 = set(cnpj0)
matches01 = list(set1.intersection(set2))
dta11  = dta0_11.loc[dta0_11['CNPJ do fundo'].isin(matches01)]
rent1M = data0_0.loc[data0_0['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
dta11 = dta11.merge(rent1M, how='inner', on='CNPJ do fundo')

set1 = set(cnpj0)
set2 = set(cnpj1)
matches01 = list(set1.intersection(set2))
data0  = data0_0.loc[data0_0['CNPJ do fundo'].isin(matches01)]
rent1M = data0_1.loc[data0_1['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
data0 = data0.merge(rent1M, how='inner', on='CNPJ do fundo')


set1 = set(cnpj1)
set2 = set(cnpj2)
matches01 = list(set1.intersection(set2))
data1  = data0_1.loc[data0_1['CNPJ do fundo'].isin(matches01)]
rent1M = data0_2.loc[data0_2['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
data1 = data1.merge(rent1M, how='inner', on='CNPJ do fundo')


set1 = set(cnpj2)
set2 = set(cnpj3)
matches01 = list(set1.intersection(set2))
data2  = data0_2.loc[data0_2['CNPJ do fundo'].isin(matches01)]
rent1M = data0_3.loc[data0_3['CNPJ do fundo'].isin(matches01)][['CNPJ do fundo','Rentabilidade No mês']]
rent1M['Rentabilidade 1M'] = rent1M['Rentabilidade No mês']
rent1M.drop(columns='Rentabilidade No mês', inplace=True)
data2 = data2.merge(rent1M, how='inner', on='CNPJ do fundo')

data = pd.concat([ dta01, dta02, dta03, dta04, dta05, dta06, dta07, dta08, dta09, dta10, dta11, data0, data1, data2], ignore_index=True)


data.dropna(axis=0, inplace=True)
data.drop(columns=feat_drop, inplace=True)
data.reset_index(drop=True, inplace=True)

data['Cluster'] = 1
data['Cluster'].loc[ data['Rentabilidade 1M'] < (data['Rentabilidade 1M'].mean() - 0.5*data['Rentabilidade 1M'].std())] = 0
data['Cluster'].loc[ data['Rentabilidade 1M'] > (data['Rentabilidade 1M'].mean() + 0.5*data['Rentabilidade 1M'].std())] =  2

#data.drop(columns='Rentabilidade 1M', inplace=True)

# %%
new_names = ['CNPJ do fundo', '1-Month Profit','3-Month Profit','6-Month Profit','12-Month Profit','24-Month Profit',
'1-Month Volatility','3-Month Volatility','6-Month Volatility','12-Month Volatility','24-Month Volatility',
'1-Month Beta','3-Month Beta','6-Month Beta','12-Month Beta','24-Month Beta',
'1-Month Tracking Error','3-Month Tracking Error','6-Month Tracking Error','12-Month Tracking Error','24-Month Tracking Error',
'1-Month Sharpe Ratio','3-Month Sharpe Ratio','6-Month Sharpe Ratio','12-Month Sharpe Ratio','24-Month Sharpe Ratio',
'1-Month Sortino Ratio','3-Month Sortino Ratio','6-Month Sortino Ratio','12-Month Sortino Ratio','24-Month Sortino Ratio',
'1-Month Information Ratio','3-Month Information Ratio','6-Month Information Ratio','12-Month Information Ratio','24-Month Information Ratio',
'1-Month Treynor Index','3-Month Treynor Index','6-Month Treynor Index','12-Month Treynor Index','24-Month Treynor Index',
'36-Month Profit','48-Month Profit','60-Month Profit','120-Month Profit',
'36-Month Volatility','48-Month Volatility','60-Month Volatility','120-Month Volatility',
'36-Month Beta','48-Month Beta','60-Month Beta','120-Month Beta',
'36-Month Tracking Error','48-Month Tracking Error','60-Month Tracking Error','120-Month Tracking Error',
'36-Month Sharpe Ratio','48-Month Sharpe Ratio','60-Month Sharpe Ratio','120-Month Sharpe Ratio',
'36-Month Sortino Ratio','48-Month Sortino Ratio','60-Month Sortino Ratio','120-Month Sortino Ratio',
'36-Month Information Ratio','48-Month Information Ratio','60-Month Information Ratio','120-Month Information Ratio',
'36-Month Treynor Index','48-Month Treynor Index','60-Month Treynor Index','120-Month Treynor Index', 'Rentabilidade 1M', 'Class']


data.columns = new_names
data
# Out:
#        CNPJ do fundo  1-Month Profit  3-Month Profit  6-Month Profit  \
# 0     13950062000106        0.045134       -0.117370        0.050586
# 1      3929711000133        0.047141       -0.012793        0.068865
# 2      3904236000140        0.046392       -0.014381        0.065438
# 3      3917776000169        0.047704       -0.013920        0.066603
# 4      3914671000156        0.047510       -0.010284        0.068547
# ...              ...             ...             ...             ...
# 4965  67976449000160        0.008526        0.009829        0.090006
# 4966  56824857000180       -0.001198        0.005155        0.073624
# 4967  74055922000132        0.006550        0.002418        0.069846
# 4968  67976423000112        0.007336        0.004868        0.075214
# 4969  88198056000143        0.013147       -0.006632       -0.028891
#
#       12-Month Profit  24-Month Profit  1-Month Volatility  \
# 0           -0.070121        -0.227474            0.190753
# 1            0.291692         0.992360            0.408596
# 2            0.283348         0.967376            0.408141
# 3            0.285244         0.970398            0.409088
# 4            0.287934         0.975874            0.408691
# ...               ...              ...                 ...
# 4965         0.219506         0.126052            0.147027
# 4966         0.158917        -0.214027            0.128773
# 4967         0.198901         0.096558            0.147057
# 4968         0.211160         0.119807            0.146854
# 4969         0.221811         0.074647            0.160655
#
#       3-Month Volatility  6-Month Volatility  12-Month Volatility  ...  \
# 0               0.228272            0.204698             0.196921  ...
# 1               0.404824            0.434350             0.396246  ...
# 2               0.404529            0.434264             0.396307  ...
# 3               0.405237            0.434668             0.396849  ...
# 4               0.405568            0.435969             0.398081  ...
# ...                  ...                 ...                  ...  ...
# 4965            0.132832            0.146756             0.159573  ...
# 4966            0.124416            0.138134             0.152219  ...
# 4967            0.135088            0.147830             0.155002  ...
# 4968            0.134897            0.147623             0.154768  ...
# 4969            0.151835            0.167840             0.177281  ...
#
#       36-Month Information Ratio  48-Month Information Ratio  \
# 0                      -0.455287                    0.329760
# 1                       0.659993                    0.420368
# 2                       0.638095                    0.397610
# 3                       0.640010                    0.400717
# 4                       0.644709                    0.404274
# ...                          ...                         ...
# 4965                   -5.824441                   -6.920392
# 4966                   -3.069346                   -2.154561
# 4967                   -0.828622                   -0.981528
# 4968                   -0.583304                   -0.742787
# 4969                   -0.560686                   -0.466712
#
#       60-Month Information Ratio  120-Month Information Ratio  \
# 0                       0.266957                     0.210171
# 1                       0.453069                     0.136915
# 2                       0.429924                     0.132156
# 3                       0.433043                     0.134170
# 4                       0.436656                     0.144700
# ...                          ...                          ...
# 4965                   -7.881623                    -9.556912
# 4966                   -1.990746                    -1.864686
# 4967                   -0.723521                    -0.767332
# 4968                   -0.469042                    -0.439997
# 4969                    0.095343                    -0.017767
#
#       36-Month Treynor Index  48-Month Treynor Index  60-Month Treynor Index  \
# 0                  -0.075142                0.054027                0.046860
# 1                   0.166551                0.098733                0.107923
# 2                   0.161023                0.093387                0.102419
# 3                   0.161618                0.094179                0.103239
# 4                   0.162762                0.094991                0.104080
# ...                      ...                     ...                     ...
# 4965               -0.014855               -0.015750               -0.016251
# 4966               -0.233362               -0.175200               -0.149357
# 4967               -0.038746               -0.045864               -0.032310
# 4968               -0.027400               -0.034859               -0.021036
# 4969               -0.062930               -0.065704                0.013309
#
#       120-Month Treynor Index  Rentabilidade 1M  Class
# 0                    0.062370         -0.042818      0
# 1                    0.030779         -0.024727      0
# 2                    0.029766         -0.025148      0
# 3                    0.030248         -0.024894      0
# 4                    0.032563         -0.025223      0
# ...                       ...               ...    ...
# 4965                -0.015647         -0.008414      1
# 4966                -0.128372         -0.002484      1
# 4967                -0.027204         -0.006378      1
# 4968                -0.015656         -0.005533      1
# 4969                -0.005159          0.026454      1
#
# [4970 rows x 75 columns]

# %%
data[['Rentabilidade 1M']].loc[data['Class'] == 0].describe()
# Out:
#        Rentabilidade 1M
# count       1683.000000
# mean          -0.057537
# std            0.028733
# min           -0.371327
# 25%           -0.073548
# 50%           -0.050458
# 75%           -0.036692
# max           -0.022210

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# custom_params = {"axes.spines.right": False, "axes.spines.top": False, "axes.grid":False}
custom_params = { "axes.grid":False}
# sns.set_theme(style="ticks", rc=custom_params, palette="pastel")

sns.set_theme(style="whitegrid", palette="pastel", rc=custom_params,)

plt.figure(figsize=(4,3))
ax = sns.histplot(
    data, x='Rentabilidade 1M', hue="Class",
    stat="count", common_norm=False,  fill=True, palette='tab10',bins=70, kde=False,
)
ax.set_xlabel('$R^{1M}_{t+1}$', fontsize=16)
ax.set_ylabel( 'Count', fontsize=16)
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
ax.set_ylim([0,500])
        
plt.savefig(f'Data_original1M.pdf', format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
s = setup(data, target = 'Class', session_id=123, transformation = True, transformation_method='quantile', train_size=0.8, ignore_features=['CNPJ do fundo'])
# Out:
# <style type="text/css">
# #T_f1a03_row9_col1, #T_f1a03_row13_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f1a03">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f1a03_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_f1a03_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f1a03_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f1a03_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_f1a03_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f1a03_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f1a03_row1_col1" class="data row1 col1" >Class</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f1a03_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_f1a03_row2_col1" class="data row2 col1" >Multiclass</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f1a03_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_f1a03_row3_col1" class="data row3 col1" >(4970, 75)</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f1a03_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_f1a03_row4_col1" class="data row4 col1" >(4970, 74)</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f1a03_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_f1a03_row5_col1" class="data row5 col1" >(3976, 74)</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f1a03_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_f1a03_row6_col1" class="data row6 col1" >(994, 74)</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f1a03_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_f1a03_row7_col1" class="data row7 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f1a03_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_f1a03_row8_col1" class="data row8 col1" >73</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f1a03_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_f1a03_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f1a03_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_f1a03_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f1a03_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_f1a03_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f1a03_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_f1a03_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f1a03_row13_col0" class="data row13 col0" >Transformation</td>
#       <td id="T_f1a03_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f1a03_row14_col0" class="data row14 col0" >Transformation method</td>
#       <td id="T_f1a03_row14_col1" class="data row14 col1" >quantile</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f1a03_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_f1a03_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f1a03_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_f1a03_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f1a03_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_f1a03_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f1a03_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_f1a03_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f1a03_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_f1a03_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f1a03_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_f1a03_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f1a03_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f1a03_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_f1a03_row21_col1" class="data row21 col1" >4208</td>
#     </tr>
#   </tbody>
# </table>

# %%
dataset_transformed = get_config('dataset_transformed')
dataset_transformed
# Out:
#       1-Month Profit  3-Month Profit  6-Month Profit  12-Month Profit  \
# 738        -0.458229       -0.842390       -1.130592        -1.263588
# 1854        0.829927        0.455947       -0.583220        -0.203405
# 608        -2.057654       -1.716406       -1.734327        -2.146666
# 4203        0.534723        1.358502        1.395721        -0.694745
# 2840       -0.318677       -0.711979        0.070316        -0.488995
# ...              ...             ...             ...              ...
# 1265       -0.309831       -1.228761       -1.341482        -1.062268
# 2443       -0.744676        0.390227        1.350048         0.488331
# 3286       -1.062671       -1.341254        0.540383        -1.128422
# 1236       -0.258979       -1.386443       -1.315678        -0.526099
# 4555       -0.715837        0.667943       -0.424920         0.102672
#
#       24-Month Profit  1-Month Volatility  3-Month Volatility  \
# 738         -0.563778            0.271267            0.074825
# 1854        -0.715606           -1.271139            0.166237
# 608         -1.950536            0.861533            1.378713
# 4203         0.689063           -0.028281            0.435086
# 2840        -0.460663            0.191479           -0.304489
# ...               ...                 ...                 ...
# 1265        -1.737918            0.898656            0.633932
# 2443         0.802984           -1.152584           -1.111207
# 3286        -0.090275            0.902583            0.382712
# 1236        -0.639243            0.361884           -0.060921
# 4555         0.496841           -1.012248           -0.713975
#
#       6-Month Volatility  12-Month Volatility  24-Month Volatility  ...  \
# 738             0.508986             0.276884             0.020879  ...
# 1854           -0.344177            -0.405233            -0.700940  ...
# 608             1.319559             0.924469             0.693050  ...
# 4203            0.584427             0.598787             0.846130  ...
# 2840           -0.657284            -0.442702            -0.432257  ...
# ...                  ...                  ...                  ...  ...
# 1265            0.593765             0.505537             0.360698  ...
# 2443           -1.090087            -0.771261            -0.900323  ...
# 3286           -0.094584             0.453697             0.579503  ...
# 1236            0.065536             0.068534            -0.124907  ...
# 4555           -0.533455            -1.071209            -0.744006  ...
#
#       36-Month Information Ratio  48-Month Information Ratio  \
# 738                    -0.295159                   -0.292685
# 1854                    0.345026                    0.252256
# 608                    -0.676918                   -0.657669
# 4203                    0.366401                    0.910499
# 2840                   -1.167652                   -0.883079
# ...                          ...                         ...
# 1265                   -0.207755                    0.275613
# 2443                    0.977695                    1.725741
# 3286                   -0.284674                   -0.298926
# 1236                   -0.025247                   -0.554582
# 4555                   -0.316764                   -1.072421
#
#       60-Month Information Ratio  120-Month Information Ratio  \
# 738                    -0.501851                     0.050866
# 1854                   -0.273893                    -0.352105
# 608                    -0.766879                    -0.708735
# 4203                    0.420968                     0.288385
# 2840                   -0.684934                    -0.512359
# ...                          ...                          ...
# 1265                    0.527594                     1.494362
# 2443                    2.388963                     2.274378
# 3286                   -0.103447                    -0.149714
# 1236                   -0.532473                     0.077447
# 4555                   -0.847573                    -0.940650
#
#       36-Month Treynor Index  48-Month Treynor Index  60-Month Treynor Index  \
# 738                -0.349335               -0.320535               -0.549642
# 1854                0.347665                0.287141               -0.511050
# 608                -1.716461               -1.472646               -1.606018
# 4203                0.450111                1.117937                0.818313
# 2840               -1.864022               -1.439330               -1.292345
# ...                      ...                     ...                     ...
# 1265               -0.561030                0.291387                0.469532
# 2443                0.724654                0.701719                1.134628
# 3286               -0.666815               -0.553354               -0.112722
# 1236               -0.024760               -0.524900               -0.522358
# 4555               -0.130078               -1.053280               -0.834534
#
#       120-Month Treynor Index  Rentabilidade 1M  Class
# 738                  0.050494         -0.067454      1
# 1854                -0.638952          0.696008      2
# 608                 -1.542544         -1.044114      0
# 4203                 0.477679         -2.325402      0
# 2840                -1.091975         -1.088379      0
# ...                       ...               ...    ...
# 1265                 1.187894          1.771509      2
# 2443                 1.837633         -0.069681      1
# 3286                -0.157729          1.989444      2
# 1236                 0.057390          0.815107      2
# 4555                -0.698809          0.079601      1
#
# [4970 rows x 74 columns]

# %%
import seaborn as sns

# custom_params = {"axes.spines.right": False, "axes.spines.top": False, "axes.grid":False}
custom_params = { "axes.grid":False}
# sns.set_theme(style="ticks", rc=custom_params, palette="pastel")

sns.set_theme(style="whitegrid", palette="pastel", rc=custom_params,)

plt.figure(figsize=(4,3))
ax = sns.histplot(
    dataset_transformed, x='Rentabilidade 1M', hue="Class",
    stat="count", common_norm=False,  fill=True, palette='tab10',bins=70, kde=False,
)
ax.set_xlabel('$R^{1M}_{t+1}$', fontsize=16)
ax.set_ylabel( 'Count', fontsize=16)
ax.tick_params(axis='x', labelsize=14)
ax.tick_params(axis='y', labelsize=14)
ax.set_ylim([0,500])
        
plt.savefig(f'Data_transformed1M.pdf', format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)
plt.show()

# %%
data.loc[data['Class']==2]['Rentabilidade 1M'].describe()
# Out:
# count    1413.000000
# mean        0.086422
# std         0.040091
# min         0.041519
# 25%         0.056562
# 50%         0.080719
# 75%         0.106506
# max         0.565069
# Name: Rentabilidade 1M, dtype: float64

# %%
data['Class']
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4965    1
# 4966    1
# 4967    1
# 4968    1
# 4969    1
# Name: Class, Length: 4970, dtype: int64

# %%
#https://jwalton.info/Embed-Publication-Matplotlib-Latex/
def set_size(width, fraction=1):
    """Set figure dimensions to avoid scaling in LaTeX.

    Parameters
    ----------
    width: float
            Document textwidth or columnwidth in pts
    fraction: float, optional
            Fraction of the width which you wish the figure to occupy

    Returns
    -------
    fig_dim: tuple
            Dimensions of figure in inches
    """
    # Width of figure (in pts)
    fig_width_pt = width * fraction

    # Convert from pt to inches
    inches_per_pt = 1 / 72.27

    # Golden ratio to set aesthetic figure height
    # https://disq.us/p/2940ij3
    golden_ratio = (5**.5 - 1) / 2

    # Figure width in inches
    fig_width_in = fig_width_pt * inches_per_pt
    # Figure height in inches
    fig_height_in = fig_width_in * golden_ratio

    fig_dim = (fig_width_in, fig_height_in)

    return fig_dim

# %%
# Using seaborn's style
plt.style.use('seaborn')
width = 345

tex_fonts = {
    # Use LaTeX to write all text
    "text.usetex": True,
    "font.family": "serif",
    # Use 10pt font in plots, to match 10pt font in document
    "axes.labelsize": 10,
    "font.size": 10,
    # Make the legend/label fonts a little smaller
    "legend.fontsize": 8,
    "xtick.labelsize": 8,
    "ytick.labelsize": 8
}

plt.rcParams.update(tex_fonts)

fig, ax = plt.subplots(1, 1, figsize=set_size(width))
ax = sns.histplot(
    dataset_transformed, x='Rentabilidade 3M', hue="Cluster",
    stat="count", common_norm=False,  fill=True, palette='tab10',bins=70, kde=False,
)
ax.set_xlabel('$R^{3M}_{t+1}$', fontsize=16)
ax.set_ylabel( 'Count', fontsize=16)
#ax.set_xlabel(r'$\theta$')
#ax.set_ylabel(r'$\sin (\theta)$')
fig.savefig(f'Data_transformed.pdf', format='pdf', dpi=300, bbox_inches='tight', pad_inches=0.1)

# Save and remove excess whitespace
#fig.savefig('example_1.pdf', format='pdf', bbox_inches='tight')

# %%
import matplotlib
import matplotlib.pyplot as plt

# Use LaTeX for rendering
matplotlib.rcParams["text.usetex"] = True
# load the xfrac package
matplotlib.rcParams["text.latex.preamble"].append(r'\usepackage[dvips]{graphicx}\usepackage{xfrac}')

fig = plt.figure()
ax = fig.add_subplot(111)
ax.plot([0,1],[1,0])
ax.text(.5, .5, r'$\sfrac{1}{2}$')
plt.savefig('111.ps')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[229], line 7
#       5 matplotlib.rcParams["text.usetex"] = True
#       6 # load the xfrac package
# ----> 7 matplotlib.rcParams["text.latex.preamble"].append(r'\usepackage[dvips]{graphicx}\usepackage{xfrac}')
#       9 fig = plt.figure()
#      10 ax = fig.add_subplot(111)
#
# AttributeError: 'str' object has no attribute 'append'

# %%
# check all available param
get_config()
# Out:
# {'USI',
#  'X',
#  'X_test',
#  'X_test_transformed',
#  'X_train',
#  'X_train_transformed',
#  'X_transformed',
#  '_available_plots',
#  '_ml_usecase',
#  'data',
#  'dataset',
#  'dataset_transformed',
#  'exp_id',
#  'exp_name_log',
#  'fix_imbalance',
#  'fold_generator',
#  'fold_groups_param',
#  'fold_shuffle_param',
#  'gpu_n_jobs_param',
#  'gpu_param',
#  'html_param',
#  'idx',
#  'is_multiclass',
#  'log_plots_param',
#  'logging_param',
#  'memory',
#  'n_jobs_param',
#  'pipeline',
#  'seed',
#  'target_param',
#  'test',
#  'test_transformed',
#  'train',
#  'train_transformed',
#  'variable_and_property_keys',
#  'variables',
#  'y',
#  'y_test',
#  'y_test_transformed',
#  'y_train',
#  'y_train_transformed',
#  'y_transformed'}

# %%
import seaborn as sns
sns.histplot(
    dataset_transformed , x='3-Month Profit', hue="Cluster",
    stat="count", common_norm=False,  fill=True, palette='tab10',bins=50, kde=True,
)
plt.show()
